# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ****Data Import****

# %%
raw_data=pd.read_csv('/content/sample_data/dirty_cafe_sales.csv')

df=raw_data.copy()

df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %% [markdown]
# # ****Initial Inspection****

# %%
def summ_and_report():

  print("Number of rows:", df.shape[0])
  print("Number of columns:", df.shape[1])

  print("\nNumber of duplicates")
  print(df.duplicated().sum())

  print("\nInfo:")
  print(df.info())

  print("\nStatistical summary:")
  print(df.describe())

  print("\nNumber of missing values")
  print(df.isna().sum())

summ_and_report()
# Out:
# Number of rows: 10000
# Number of columns: 8
#
# Number of duplicates
# 0
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB
# None
#
# Statistical summary:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# ...

# %% [markdown]
# # Unique values in each column

# %%
for i in df.columns:
  print("\n","--"*80 ,"\n")
  display(df[i].unique())
# Out:
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# array(['TXN_1961373', 'TXN_4977031', 'TXN_4271903', ..., 'TXN_5255387',
#        'TXN_7695629', 'TXN_6170729'], dtype=object)
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## ****What Changes need to make ?****
# 1. **But first we need to replace 'Unknown', 'ERROR' with np.nan to show it as null values.**
# 2. **Assign Right Datatype to the columns.**
# 3. **Then We need to Calculate null values in `Quantity`, `Price Per Unit`, `Total Spent`.**
# 4. **For columns like `Payment Method`, `Location` missing values are missing completely at random and**
#     **these column does not form any relation with others so we can fill missing values in these column using random sample method.**
# 5. **For `Transaction Date` Column we can calculate missig using interpolate method.**

# %% [markdown]
# ## ****Replace 'ERROR', 'UNKNOWN' values in data as `Null`****

# %%
df.replace(['ERROR', 'UNKNOWN'], np.nan, inplace = True)

df[['Quantity', 'Price Per Unit', 'Total Spent']] = df[['Quantity', 'Price Per Unit', 'Total Spent']].astype(np.float64)

df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %% [markdown]
# ## ****Calculate null values in `Quantity`, `Price Per Unit`, `Total Spent`****
#
# - We can use formula **`Total Spent`** = **`Quantity`** * **`Price Per Unit`** to calculate missing values all three columns.

# %%
def null_calculator(df):

    df['Quantity'] = df['Quantity'].fillna(df['Total Spent'] / df['Price Per Unit'])

    df['Price Per Unit'] = df['Price Per Unit'].fillna(df['Total Spent'] / df['Quantity'])

    df['Total Spent'] = df['Total Spent'].fillna(df['Quantity'] * df['Price Per Unit'])

null_calculator(df)

# %% [markdown]
# ## ****Calculate Null in `Item` Column****
#
# - In this column we can calculate missing data using Price Per Item.
# - But there is catche that `Sandwitch` and `Smoothie` has same price so we have to randomly sample these priced values.
# - Another values like `Cake` and `Juice` has same Price and we will calculate these by same method.

# %%
def item_missing_cal(df):

    # Creating Price map
    price_map = {2.0 : 'Coffee', 1.50 : 'Tea', 5.0 : 'Salad', 1.0 : 'Cookie'}

    # Create replacement using map
    replace = df['Price Per Unit'].map(price_map)

    # Calculate missing using replacement
    df['Item'] = df['Item'].fillna(replace)

item_missing_cal(df)

# %%
# For Items at price == 3.0

def missing_item_price_3(df):

    # Item are at price == 3.0
    maping = ['Cake', 'Juice']

    # Find rows that meet criteria
    masking = ((df['Item'].isnull()) & (df['Price Per Unit'] == 3))

    # Value Count of missing
    count = masking.sum()

    # Calculate missing
    if count > 0:
        df.loc[masking, 'Item'] = np.random.choice(maping, size = count, p = [0.5, 0.5])                   # Here p = [0.5, 0.5] means it will fill 50%-50% both values.


missing_item_price_3(df)

# %%
# For Items at Price == 4.0

def missing_item_price_4(df):

    # Items at price 4
    items = ['Sandwich', 'Smoothie']

    # Find rows that meet criteria
    rows = ((df['Item'].isnull()) & (df['Price Per Unit'] == 4.0))

    # Count of these rows
    counts = rows.sum()

    # Calculate missing
    if counts > 0:
        df.loc[rows, 'Item'] = np.random.choice(items, size = counts, p = [0.5, 0.5])


missing_item_price_4(df)

# %% [markdown]
# ## ****Calculate missing in Payment method and location****

# %%
mask = df['Payment Method'].isnull()

df.loc[mask, 'Payment Method'] = (
    df['Payment Method']
    .dropna()
    .sample(mask.sum())
    .values
)

df['Location'][df['Location'].isnull()] = df['Location'].dropna().sample(df['Location'].isnull().sum()).values

mask = df['Location'].isnull()

df.loc[mask, 'Location'] = (
    df['Location']
    .dropna()
    .sample(mask.sum())
    .values
)
# Out:
# /tmp/ipykernel_165/3414590212.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Location'][df['Location'].isnull()] = df['Location'].dropna().sample(df['Location'].isnull().sum()).values
# ...

# %% [markdown]
# ## ****Calculate null in Transaction Date column****

# %%
numeric_date = df['Transaction Date'].view('int64')

numeric_date = numeric_date.where(df['Transaction Date'].notna(), np.nan)

df['Transaction Date'] = pd.to_datetime(numeric_date.interpolate(method = 'linear'))

#df['Transaction Date']
# Out:
# /tmp/ipykernel_165/2252086455.py:1: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   numeric_date = df['Transaction Date'].view('int64')

# %% [markdown]
# # ****Drop Rows Which has null values in `Item`, `Price Per Unit` and `Quantity`****
#
# - Dropping these because we are not able to find missing data by just `Total Spent` columns.

# %%
df = df.dropna(subset = ['Item', 'Quantity', 'Price Per Unit'], how = 'all')

# %% [markdown]
# Find Missing in Price Per Unit using Item column

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'Sandwich',
#        'Juice', 'Tea', nan], dtype=object)

# %%
def priceperunit_missing(df):

    maping = {'Coffee' : 2.0, 'Cake' : 3.0, 'Cookie' : 1.0, 'Salad' : 5.0, 'Smoothie' : 4.0, 'Sandwich' : 4.0, 'Tea' : 1.50, 'Juice' : 3.0}

    replace = df['Item'].map(maping)

    df['Price Per Unit'] = df['Price Per Unit'].fillna(replace)

priceperunit_missing(df)
null_calculator(df)

# %%
df.isnull().sum()
# Out:
# Transaction ID       0
# Item                 3
# Quantity            20
# Price Per Unit       3
# Total Spent         23
# Payment Method       0
# Location             0
# Transaction Date     0
# dtype: int64

# %%
df[df['Quantity'].isnull()]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# 7029    TXN_4628338    Coffee       NaN             2.0          NaN
# 7297    TXN_9944500  Smoothie       NaN             4.0          NaN
# 8021    TXN_2428781     Salad       NaN             5.0          NaN
# ...

# %%
df[df['Item'].isna()]
# Out:
#      Transaction ID Item  Quantity  Price Per Unit  Total Spent  \
# 1761    TXN_3611851  NaN       4.0             NaN          NaN
# 2289    TXN_7524977  NaN       4.0             NaN          NaN
# 4152    TXN_9646000  NaN       2.0             NaN          NaN
#
#       Payment Method  Location Transaction Date
# 1761     Credit Card  Takeaway       2023-02-09
# 2289  Digital Wallet  Takeaway       2023-12-09
# 4152  Digital Wallet  In-store       2023-12-14

# %%
df[df['Price Per Unit'].isna()]
# Out:
#      Transaction ID Item  Quantity  Price Per Unit  Total Spent  \
# 1761    TXN_3611851  NaN       4.0             NaN          NaN
# 2289    TXN_7524977  NaN       4.0             NaN          NaN
# 4152    TXN_9646000  NaN       2.0             NaN          NaN
#
#       Payment Method  Location Transaction Date
# 1761     Credit Card  Takeaway       2023-02-09
# 2289  Digital Wallet  Takeaway       2023-12-09
# 4152  Digital Wallet  In-store       2023-12-14

# %%
df[df['Total Spent'].isna()]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 1761    TXN_3611851       NaN       4.0             NaN          NaN
# 2289    TXN_7524977       NaN       4.0             NaN          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 4152    TXN_9646000       NaN       2.0             NaN          NaN
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# ...

# %% [markdown]
# ## ****From above remaining missing data none of values can be calculated so we have to drop all these rows****

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          4.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401    Cookie       3.0             1.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             1.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
# Calculate loss
rows_lost = raw_data.shape[0] - df.shape[0]
percent_lost = (rows_lost / raw_data.shape[0]) * 100

print(f"\033[1m{' DATA CLEANING SUMMARY ':^50}\033[0m")
print("=" * 50)

print(f"{'Metric':<25} | {'Raw Data':<10} | {'Cleaned':<10}")
print("-" * 50)
print(f"{'Number of Rows':<25} | {raw_data.shape[0]:<10} | {df.shape[0]:<10}")
print(f"{'Number of Columns':<25} | {raw_data.shape[1]:<10} | {df.shape[1]:<10}")

print("-" * 50)
print(f"\033[91m{'Total Rows Removed':<25} : {rows_lost}\033[0m")
print(f"\033[91m{'Data Loss Percentage':<25} : {percent_lost:.2f}%\033[0m")
print("=" * 50)
# Out:
#               DATA CLEANING SUMMARY
# ...
# Metric                    | Raw Data   | Cleaned
# --------------------------------------------------
# Number of Rows            | 10000      | 9974
# Number of Columns         | 8          | 8
# --------------------------------------------------
# Total Rows Removed        : 26
# Data Loss Percentage      : 0.26%
# ...

# %%
df.to_csv('cafe_sales_cleaned.csv', index=False)
